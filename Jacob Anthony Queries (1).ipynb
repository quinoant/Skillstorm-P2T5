# %% [markdown]
# # README
# <p>This noteboook aims to pull from the data lake and answer the use case aggregations as outlined in the Section labeled "Questions"</p>

# %% [markdown]
# # Imports

# %%
from pyspark.sql.functions import *

# %% [markdown]
# ## Loading in Data

# %%
contname = 'team5-project2' #azure storage account container
#THIS WILL CHANGE BASED ON TEAM: 'team2-project2', 'team3-project2', etc.

storage_acct_name = '20230821desa'

client_id = 'de4ff859-02b1-4e2f-9d16-b578fa03df4f' #aka: app id

tenant_id = '33da9f3f-4c1a-4640-8ce1-3f63024aea1d' #aka: directory id

service_credential = dbutils.secrets.get(scope="databricks-app-kv",key="databricks-application")

gold_path = f'abfss://{contname}@{storage_acct_name}.dfs.core.windows.net/GoldLayer'

# %%
action = (spark.read.format('parquet')
      .option("header","true")
      .option('inferColumnTypes', True)
      .load(f"{gold_path}/factAction/part-*")).limit(100000)
action.createOrReplaceTempView('action')

# %%
timestamp = (spark.read.format('parquet')
      .option("header","true")
      .option('inferColumnTypes', True)
      .load(f"{gold_path}/dimTimestamp/part-*"))
timestamp.createOrReplaceTempView('timestamp')

# %%
commit = (spark.read.format('parquet')
      .option("header","true")
      .option('inferColumnTypes', True)
      .load(f"{gold_path}/dimCommits/part-*")).limit(100000)
commit.createOrReplaceTempView('commit')

# %%
linker_commits_action = (spark.read.format('parquet')
      .option("header","true")
      .option('inferColumnTypes', True)
      .load(f"{gold_path}/linker_commits_action/part-*")).limit(100000)
linker_commits_action.createOrReplaceTempView('linker_commits_action')

# %%
pull_request = (spark.read.format('parquet')
      .option("header","true")
      .option('inferColumnTypes', True)
      .load(f"{gold_path}/dimPullRequests/part-*")).limit(10000)
pull_request.createOrReplaceTempView('pull_request')

# %%
repo = (spark.read.format('parquet')
      .option("header","true")
      .option('inferColumnTypes', True)
      .load(f"{gold_path}/dimRepos/part-*")).limit(100000)
repo.createOrReplaceTempView('repo')

# %%
repo_names = (spark.read.format('parquet')
      .option("header","true")
      .option('inferColumnTypes', True)
      .load(f"{gold_path}/repo_names/part-*")).limit(100000)
repo_names.createOrReplaceTempView('repo_names')

# %%
user = (spark.read.format('parquet')
      .option("header","true")
      .option('inferColumnTypes', True)
      .load(f"{gold_path}/dimUser/part-*")).limit(100000)
user.createOrReplaceTempView('user')

# %% [markdown]
# # Questions

# %% [markdown]
# Once the data has been preprocessed in the silver layer, you have several aggregations that need to be done for the gold layer. Sparrow Analytics will load your gold layer into a Data Warehouse (and, eventually a BI tool) to provide insights into GitHub use patterns. Data loaded into the gold layer should adhere to a flat, star, or snowflake schema. You are tasked with the following aggregations:
#
# Data aggregated by type of GitHub event per hour
# PushEvent data aggregated by ref type – whether the commit is on the main branch
# Breakdown of events by type and number of commits per event
# User activity should be aggregated so that a filterable chart can be populated with breakdowns of user activity by week or month.
# Breakdown of activity by project – find a unique use case
# Challenge: Based on the commit messages – breakdown the events by language
# <ul>
#   <li>Data aggregated by type of GitHub event per hour ?</li>
#   <li>PushEvent data aggregated by ref type – whether the commit is on the main branch</li>
#   <li>Breakdown of events by type and number of commits per event </li>
#   <li>User activity should be aggregated so that a filterable chart can be populated with breakdowns of user activity by week or month. </li>
#   <li>Breakdown of activity by project – find a unique use case </li>
#   <li>Challenge: Based on the commit messages – breakdown the events by language </li>
# </ul>

# %% [markdown]
# ## Per Hour
# <p>Group the number of Events per hour</P>

# %%
#answer
action.join(timestamp, action.time_id == timestamp.time_id).groupBy('year_created','day_created','hour_created','action_type').count().sort('hour_created',ascending=False).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year_created</th><th>day_created</th><th>hour_created</th><th>action_type</th><th>count</th></tr></thead><tbody><tr><td>2022</td><td>1</td><td>23</td><td>PushEvent</td><td>16</td></tr><tr><td>2022</td><td>1</td><td>23</td><td>IssueCommentEvent</td><td>3</td></tr><tr><td>2022</td><td>1</td><td>23</td><td>CreateEvent</td><td>9</td></tr><tr><td>2022</td><td>1</td><td>23</td><td>WatchEvent</td><td>1</td></tr><tr><td>2022</td><td>1</td><td>23</td><td>PullRequestReviewEvent</td><td>2</td></tr><tr><td>2022</td><td>1</td><td>23</td><td>PullRequestEvent</td><td>3</td></tr><tr><td>2022</td><td>2</td><td>23</td><td>PushEvent</td><td>28</td></tr><tr><td>2022</td><td>2</td><td>23</td><td>DeleteEvent</td><td>1</td></tr><tr><td>2022</td><td>2</td><td>23</td><td>CreateEvent</td><td>6</td></tr><tr><td>2022</td><td>2</td><td>23</td><td>WatchEvent</td><td>1</td></tr><tr><td>2022</td><td>2</td><td>23</td><td>ForkEvent</td><td>1</td></tr><tr><td>2022</td><td>2</td><td>23</td><td>PullRequestEvent</td><td>1</td></tr><tr><td>2022</td><td>3</td><td>23</td><td>CreateEvent</td><td>11</td></tr><tr><td>2022</td><td>3</td><td>23</td><td>PushEvent</td><td>28</td></tr><tr><td>2022</td><td>3</td><td>23</td><td>PullRequestEvent</td><td>5</td></tr><tr><td>2022</td><td>3</td><td>23</td><td>IssueCommentEvent</td><td>5</td></tr><tr><td>2022</td><td>3</td><td>23</td><td>DeleteEvent</td><td>1</td></tr><tr><td>2022</td><td>3</td><td>23</td><td>PullRequestReviewEvent</td><td>2</td></tr><tr><td>2022</td><td>3</td><td>23</td><td>WatchEvent</td><td>4</td></tr><tr><td>2022</td><td>4</td><td>23</td><td>PushEvent</td><td>22</td></tr><tr><td>2022</td><td>4</td><td>23</td><td>PullRequestReviewEvent</td><td>2</td></tr><tr><td>2022</td><td>4</td><td>23</td><td>IssuesEvent</td><td>2</td></tr><tr><td>2022</td><td>4</td><td>23</td><td>IssueCommentEvent</td><td>1</td></tr><tr><td>2022</td><td>4</td><td>23</td><td>PullRequestEvent</td><td>9</td></tr><tr><td>2022</td><td>4</td><td>23</td><td>ReleaseEvent</td><td>1</td></tr><tr><td>2022</td><td>4</td><td>23</td><td>CreateEvent</td><td>2</td></tr><tr><td>2022</td><td>4</td><td>23</td><td>DeleteEvent</td><td>3</td></tr><tr><td>2022</td><td>4</td><td>23</td><td>WatchEvent</td><td>2</td></tr><tr><td>2022</td><td>5</td><td>23</td><td>PushEvent</td><td>47</td></tr><tr><td>2022</td><td>5</td><td>23</td><td>CreateEvent</td><td>5</td></tr><tr><td>2022</td><td>5</td><td>23</td><td>IssuesEvent</td><td>2</td></tr><tr><td>2022</td><td>5</td><td>23</td><td>CommitCommentEvent</td><td>1</td></tr><tr><td>2022</td><td>5</td><td>23</td><td>IssueCommentEvent</td><td>6</td></tr><tr><td>2022</td><td>5</td><td>23</td><td>PullRequestReviewCommentEvent</td><td>2</td></tr><tr><td>2022</td><td>5</td><td>23</td><td>PullRequestReviewEvent</td><td>2</td></tr><tr><td>2022</td><td>5</td><td>23</td><td>PullRequestEvent</td><td>3</td></tr><tr><td>2022</td><td>5</td><td>23</td><td>DeleteEvent</td><td>1</td></tr><tr><td>2022</td><td>5</td><td>23</td><td>ForkEvent</td><td>1</td></tr><tr><td>2022</td><td>5</td><td>23</td><td>WatchEvent</td><td>3</td></tr><tr><td>2022</td><td>5</td><td>23</td><td>ReleaseEvent</td><td>1</td></tr><tr><td>2022</td><td>6</td><td>23</td><td>PullRequestEvent</td><td>7</td></tr><tr><td>2022</td><td>6</td><td>23</td><td>PushEvent</td><td>38</td></tr><tr><td>2022</td><td>6</td><td>23</td><td>CreateEvent</td><td>9</td></tr><tr><td>2022</td><td>6</td><td>23</td><td>WatchEvent</td><td>2</td></tr><tr><td>2022</td><td>6</td><td>23</td><td>GollumEvent</td><td>1</td></tr><tr><td>2022</td><td>6</td><td>23</td><td>DeleteEvent</td><td>2</td></tr><tr><td>2022</td><td>6</td><td>23</td><td>PullRequestReviewEvent</td><td>1</td></tr><tr><td>2022</td><td>6</td><td>23</td><td>IssueCommentEvent</td><td>2</td></tr><tr><td>2022</td><td>7</td><td>23</td><td>PullRequestEvent</td><td>2</td></tr><tr><td>2022</td><td>7</td><td>23</td><td>PushEvent</td><td> ...

# %% [markdown]
# ## Main branch? (By Event Type)
# <p>Determine whether or not the commit was on the main / master branch</p>

# %%
# %sql
-- Grabs the pull_request_id and whether or not the base_name is on main from pull_request
-- Then joins action on pull_request_id.
-- Finally groups by the event (action)
SELECT a.action,
 count(t1.Bool) as Count_Per_Event_on_main
FROM (
  SELECT pull_request_id, 
    CASE WHEN pull_request_base_name LIKE '%master'  OR pull_request_base_name like '%main'
      THEN TRUE 
    ELSE FALSE
  END as Bool
  FROM pull_request
) t1
JOIN action a on t1.pull_request_id == a.action_pull_request_id
GROUP BY a.action
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>Count_Per_Event_on_main</th></tr></thead><tbody><tr><td>closed</td><td>56</td></tr><tr><td>created</td><td>1675</td></tr><tr><td>reopened</td><td>4</td></tr></tbody></table></div>

# %% [markdown]
# ## Breakdown of events by type and number of commits per event
# <p>Counts the number of commits per event type</p>

# %%
#answer, they are all Push Events
commit_linked = commit.join(linker_commits_action,commit.commit_url == linker_commits_action.commit_url,'inner')
commit_linked.join(action, commit_linked.action_id == action.action_id, 'inner').groupBy('action_type').count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action_type</th><th>count</th></tr></thead><tbody><tr><td>PushEvent</td><td>23817936</td></tr></tbody></table></div>

# %% [markdown]
# ## User activity should be aggregated so that a filterable chart can be populated with breakdowns of user activity by week or month

# %%
# %sql
SELECT month_created, count(action.action_actor_id) FROM user JOIN action
ON user.user_id == action.action_actor_id
JOIN timestamp on timestamp.time_id == action.time_id
group by month_created
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month_created</th><th>count(action_actor_id)</th></tr></thead><tbody><tr><td>1</td><td>1479</td></tr></tbody></table></div>

# %%
# %sql
SELECT number_of_week_created, count(action.action_actor_id) FROM user JOIN action
ON user.user_id == action.action_actor_id
JOIN timestamp on timestamp.time_id == action.time_id
group by number_of_week_created
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>number_of_week_created</th><th>count(action_actor_id)</th></tr></thead><tbody><tr><td>1</td><td>340</td></tr><tr><td>52</td><td>58</td></tr><tr><td>3</td><td>335</td></tr><tr><td>5</td><td>48</td></tr><tr><td>4</td><td>371</td></tr><tr><td>2</td><td>327</td></tr></tbody></table></div>

# %%
# %sql
SELECT month_created, number_of_week_created, count(t1.action_actor_id) 
FROM (user JOIN action
ON user.user_id == action.action_actor_id
JOIN timestamp on timestamp.time_id == action.time_id) t1
group by number_of_week_created, month_created
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month_created</th><th>number_of_week_created</th><th>count(action_actor_id)</th></tr></thead><tbody><tr><td>1</td><td>3</td><td>335</td></tr><tr><td>1</td><td>1</td><td>340</td></tr><tr><td>1</td><td>2</td><td>327</td></tr><tr><td>1</td><td>52</td><td>58</td></tr><tr><td>1</td><td>5</td><td>48</td></tr><tr><td>1</td><td>4</td><td>371</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ## Breakdown of activity by project – find a unique use case

# %%
#How many actions of each type for each repo_url
action.join(repo,action.action_repo_id == repo.repo_id,'inner').groupBy('repo_url','action_type').count().sort('repo_url').withColumnRenamed('count','Total Actions').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>repo_url</th><th>action_type</th><th>Total Actions</th></tr></thead><tbody><tr><td>https://api.github.com/repos/0xStefan214/javascript-files</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/0xsequence/erc-1155</td><td>WatchEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/117010130/hello-world</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/1Password/scim-examples</td><td>PullRequestReviewEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/4vent/ArcadeTools</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/8fn/exercicios-php</td><td>PublicEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/ABHINAV-GOPINADH/java-expt-2</td><td>CreateEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/AIAcademyBatchH/TensorFlow_ANN</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/AIT-LAHCEN/Extranet_RH</td><td>CreateEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/Abh1shekSingh/Coursera_Solution</td><td>CreateEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/AbsoluteWebServices/magento2</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/Adipiscing/Dedi</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/Afolayanoluwadamilola/Hamoye-Quiz</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/Albahd/bootcamp-fullstack-mad-enero-2022</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/AleksandrPanov/opencv_contrib</td><td>PullRequestReviewEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/AlexM2701/Android</td><td>CreateEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/AlexeyShamsutdinov/Test-11111111112222222222333333</td><td>CreateEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/Almouro/flipper</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/AlySnyder/unreal-talk</td><td>PublicEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/AncientSoup/AncientSoup</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/AntonVelychko/SagemakerTraining</td><td>IssueCommentEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/AppsDevTeam/mfaktury</td><td>ReleaseEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/AreebE/Superhero</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/Arpan-tech-create/INSTA-UI</td><td>DeleteEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/Asifakhan1103/WillowStuff</td><td>CreateEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/AvarianKnight/pma-voice</td><td>ReleaseEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/Azhaar3/Wep-Application</td><td>CreateEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/B14ckP4nd4/tronscan</td><td>CreateEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/Baiterade/Portfolio</td><td>WatchEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/BelyakovaA031221/BelyakovaA011221</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/BenasVolkovas/BenasVolkovas</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/BhaveshBhavu/upload</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/BilgisayarKavramlari/Programlamaya-Giris</td><td>ForkEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/BlackSapce/Portfolio</td><td>CreateEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/Blobirb/island</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/Booooms/Algorithm-PS</td><td>PushEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/BornToBeRoot/NETworkManager</td><td>DeleteEvent</td><td>1</td></tr><tr><td>https://api.github.com/repos/BornToBeRoot/NET ...

# %%
#Repos with two or more actions
action.join(repo,action.action_repo_id == repo.repo_id,'inner').groupBy('repo_url').count().sort('repo_url').filter('count > 1').withColumnRenamed('count','Total Actions').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>repo_url</th><th>Total Actions</th></tr></thead><tbody><tr><td>https://api.github.com/repos/BornToBeRoot/NETworkManager</td><td>2</td></tr><tr><td>https://api.github.com/repos/CSeanXu/b1llion</td><td>6</td></tr><tr><td>https://api.github.com/repos/CaeCur/lights-out</td><td>2</td></tr><tr><td>https://api.github.com/repos/Codecademy/gamut</td><td>4</td></tr><tr><td>https://api.github.com/repos/DataDog/documentation</td><td>4</td></tr><tr><td>https://api.github.com/repos/DimensionDev/Maskbook</td><td>3</td></tr><tr><td>https://api.github.com/repos/DonQuixoteJoker/Wabo</td><td>2</td></tr><tr><td>https://api.github.com/repos/EthereansOS/ITEMS-swap</td><td>2</td></tr><tr><td>https://api.github.com/repos/GuruCICDCanary-Prod-Release/CICDCanary</td><td>13</td></tr><tr><td>https://api.github.com/repos/Jason2866/tmp_copy</td><td>2</td></tr><tr><td>https://api.github.com/repos/LagradOst/CloudStream-3</td><td>5</td></tr><tr><td>https://api.github.com/repos/LoveOctocat/RSSHub</td><td>2</td></tr><tr><td>https://api.github.com/repos/NubeIO/rubix-service</td><td>2</td></tr><tr><td>https://api.github.com/repos/PostHog/posthog</td><td>9</td></tr><tr><td>https://api.github.com/repos/Roo7K1d/status-page</td><td>4</td></tr><tr><td>https://api.github.com/repos/SarahYousryM/Kalbonyan-Elmarsos-1</td><td>2</td></tr><tr><td>https://api.github.com/repos/Shah-Arsalan/frid-component-library</td><td>2</td></tr><tr><td>https://api.github.com/repos/SickChill/SickChill</td><td>2</td></tr><tr><td>https://api.github.com/repos/Tackyon-Dream-Team/Tackyon-Dream-Team</td><td>2</td></tr><tr><td>https://api.github.com/repos/TeamBeMyPlan/BeMyPlan-iOS</td><td>2</td></tr><tr><td>https://api.github.com/repos/TeamFILL-IN/Fill-Server</td><td>2</td></tr><tr><td>https://api.github.com/repos/algorand/go-algorand</td><td>3</td></tr><tr><td>https://api.github.com/repos/andre2300/jhs929</td><td>5</td></tr><tr><td>https://api.github.com/repos/aristanetworks/ansible-avd</td><td>3</td></tr><tr><td>https://api.github.com/repos/autonomousapps/dependency-analysis-android-gradle-plugin</td><td>2</td></tr><tr><td>https://api.github.com/repos/benoitgaudou/scrap-BisonFute</td><td>2</td></tr><tr><td>https://api.github.com/repos/chowdhary-org/status</td><td>2</td></tr><tr><td>https://api.github.com/repos/confusedconsciousness/mushroom-classifier</td><td>2</td></tr><tr><td>https://api.github.com/repos/dadabricks/dust-test-public</td><td>4</td></tr><tr><td>https://api.github.com/repos/data-apis/array-api</td><td>2</td></tr><tr><td>https://api.github.com/repos/department-of-veterans-affairs/content-build</td><td>2</td></tr><tr><td>https://api.github.com/repos/dfa54/cea6449e-3b6e-4cdb-818c-624ec3b5b8f7</td><td>2</td></tr><tr><td>https://api.github.com/repos/dfa54/ee16ccb3-e29f-490f-98f1-b40adc685e05</td><td>3</td></tr><tr><td>https://api.github.com/repos/emu-russia/breaks</td><td>2</td></tr><tr><td>https://api.github.com/repos/facebook/folly</td><td>2</td></tr><tr><td>https://api.github.com/repos/fjordllc/bootcamp</td><td>2</td></tr><tr><td>https://api.github.com/repos/giantswarm/giantnetes-terraform</td><td>2</td></tr><tr><td>https://api.github.com/repos/glprsan/mattermost-webapp</td><td>2</td></tr><tr><td>https://api.github.com/repos/gollum/gollum</td><td>2</td></tr><tr><td>https://api.github.com/repos/google/jax</td><td>2</td></tr><tr><td>https://api.github.com/repos/google/site-kit-wp</td><td>2</td></tr><tr><td>https://api.github.com/repos/google/zx</td><td>6</td></tr><tr><td>https://api.github.com/repos/ibiibiibi/ibiibiibi</td><td>2</td></tr><tr><td>https://api.github.com/repos/icefight/sohappy2</td><td>2</td></tr><tr><td>https://api.github.com/repos/influxdata/docs-v2</td><td>3</td></tr><tr><td>https://api.github.com/repos/ivy-digital/gsm-upptime</td><td>5</td></tr><tr><td>https://api.github.com/repos/jamesmstone/vicemergency</td><td>2</td></tr><tr><td>https://api.github.c ...

# %%
#Actions per month for each repo_url
resault = action.join(repo,action.action_repo_id == repo.repo_id,'inner')
resault.join(timestamp, resault.time_id == timestamp.time_id,'inner').groupBy('repo_url','day_created').count().sort('repo_url','day_created').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>repo_url</th><th>day_created</th><th>count</th></tr></thead><tbody><tr><td>https://api.github.com/repos/0xStefan214/javascript-files</td><td>12</td><td>1</td></tr><tr><td>https://api.github.com/repos/0xsequence/erc-1155</td><td>24</td><td>1</td></tr><tr><td>https://api.github.com/repos/117010130/hello-world</td><td>17</td><td>1</td></tr><tr><td>https://api.github.com/repos/1Password/scim-examples</td><td>19</td><td>1</td></tr><tr><td>https://api.github.com/repos/4vent/ArcadeTools</td><td>31</td><td>1</td></tr><tr><td>https://api.github.com/repos/8fn/exercicios-php</td><td>17</td><td>1</td></tr><tr><td>https://api.github.com/repos/ABHINAV-GOPINADH/java-expt-2</td><td>25</td><td>1</td></tr><tr><td>https://api.github.com/repos/AIAcademyBatchH/TensorFlow_ANN</td><td>28</td><td>1</td></tr><tr><td>https://api.github.com/repos/AIT-LAHCEN/Extranet_RH</td><td>14</td><td>1</td></tr><tr><td>https://api.github.com/repos/Abh1shekSingh/Coursera_Solution</td><td>21</td><td>1</td></tr><tr><td>https://api.github.com/repos/AbsoluteWebServices/magento2</td><td>21</td><td>1</td></tr><tr><td>https://api.github.com/repos/Adipiscing/Dedi</td><td>8</td><td>1</td></tr><tr><td>https://api.github.com/repos/Afolayanoluwadamilola/Hamoye-Quiz</td><td>30</td><td>1</td></tr><tr><td>https://api.github.com/repos/Albahd/bootcamp-fullstack-mad-enero-2022</td><td>16</td><td>1</td></tr><tr><td>https://api.github.com/repos/AleksandrPanov/opencv_contrib</td><td>20</td><td>1</td></tr><tr><td>https://api.github.com/repos/AlexM2701/Android</td><td>20</td><td>1</td></tr><tr><td>https://api.github.com/repos/AlexeyShamsutdinov/Test-11111111112222222222333333</td><td>31</td><td>1</td></tr><tr><td>https://api.github.com/repos/Almouro/flipper</td><td>20</td><td>1</td></tr><tr><td>https://api.github.com/repos/AlySnyder/unreal-talk</td><td>28</td><td>1</td></tr><tr><td>https://api.github.com/repos/AncientSoup/AncientSoup</td><td>25</td><td>1</td></tr><tr><td>https://api.github.com/repos/AntonVelychko/SagemakerTraining</td><td>13</td><td>1</td></tr><tr><td>https://api.github.com/repos/AppsDevTeam/mfaktury</td><td>21</td><td>1</td></tr><tr><td>https://api.github.com/repos/AreebE/Superhero</td><td>26</td><td>1</td></tr><tr><td>https://api.github.com/repos/Arpan-tech-create/INSTA-UI</td><td>5</td><td>1</td></tr><tr><td>https://api.github.com/repos/Asifakhan1103/WillowStuff</td><td>31</td><td>1</td></tr><tr><td>https://api.github.com/repos/AvarianKnight/pma-voice</td><td>1</td><td>1</td></tr><tr><td>https://api.github.com/repos/Azhaar3/Wep-Application</td><td>26</td><td>1</td></tr><tr><td>https://api.github.com/repos/B14ckP4nd4/tronscan</td><td>13</td><td>1</td></tr><tr><td>https://api.github.com/repos/Baiterade/Portfolio</td><td>26</td><td>1</td></tr><tr><td>https://api.github.com/repos/BelyakovaA031221/BelyakovaA011221</td><td>19</td><td>1</td></tr><tr><td>https://api.github.com/repos/BenasVolkovas/BenasVolkovas</td><td>20</td><td>1</td></tr><tr><td>https://api.github.com/repos/BhaveshBhavu/upload</td><td>22</td><td>1</td></tr><tr><td>https://api.github.com/repos/BilgisayarKavramlari/Programlamaya-Giris</td><td>10</td><td>1</td></tr><tr><td>https://api.github.com/repos/BlackSapce/Portfolio</td><td>2</td><td>1</td></tr><tr><td>https://api.github.com/repos/Blobirb/island</td><td>20</td><td>1</td></tr><tr><td>https://api.github.com/repos/Booooms/Algorithm-PS</td><td>5</td><td>1</td></tr><tr><td>https://api.github.com/repos/BornToBeRoot/NETworkManager</td><td>7</td><td>2</td></tr><tr><td>https://api.github.com/repos/BryanLaura/shields</td><td>14</td><td>1</td></tr><tr><td>https://api.github.com/repos/CHardin10/Accounting_Software</td><td>30</td><td>1</td></tr><tr><td>https://api.github.com/repos/CNSAWatcher/cnsawatcher.github.io</td><td>14</td><td>1</td></tr><tr><td>https://api.github.com/repos/CSMPRO/nodejs-goof</td><td>7</td><td>1</td></tr><tr><td>https://api.githu ...

# %% [markdown]
# ## Attempting to set up for NLP

# %%
# !pip install spark-nlp
# Out:
# Collecting spark-nlp
#   Using cached spark_nlp-5.1.2-py2.py3-none-any.whl (536 kB)
# Installing collected packages: spark-nlp
# Successfully installed spark-nlp-5.1.2
#
# [notice] A new release of pip available: 22.2.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
from sparknlp.pretrained import PretrainedPipeline
from sparknlp.annotator import LanguageDetectorDL
from sparknlp.base import *
# Does not work due to needing to install a JAR cluster wide
# This can be found several stack overflow discussions.
# The following is a possible solution, however it did not work for us
from py4j.java_gateway import java_import
java_import(spark._sc._jvm, "org.apache.spark.sql.api.python.*")

documentAssembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")  # Will take your column name and output a diff name
